# %%
import sys
from typing import List, Tuple

def build_suffix_array(text: str) -> List[int]:
    """
    Build a suffix array for the given text.
    
    It doesn't explicitly store all suffixes.
    Instead, it sorts the indices based on the suffixes they represent.
    
    Args:
        text: The input text
        
    Returns:
        A sorted array of indices representing the suffix array
    """
    # Create a list of tuples (index, suffix)
    # Store the index and compute the suffix on-the-fly during comparison
    text = "".join([text, "$"])
    suffixes = [(i, text[i:]) for i in range(len(text))]

    # Sort based on lexicographical order of suffixes
    suffixes.sort(key=lambda x: x[1])
    
    # Extract just the indices to form the suffix array
    suffix_array = [index for index, _ in suffixes]
    
    return suffix_array

def binary_search(text: str, suffix_array: List[int], query: str) -> List[int]:
    """
    Find all occurrences of query in text using binary search on the suffix array.
    
    Args:
        text: The input text
        suffix_array: The suffix array for the text
        query: The string to search for
        
    Returns:
        A list of positions where query is found
    """
    n = len(text)
    query_len = len(query)
    positions = []
    
    #print(f"\n--- DEBUGGING BINARY SEARCH FOR QUERY: '{query}' ---")
    #print(f"Text: '{text}'")
    #print(f"Suffix Array: {suffix_array}")
    #print(f"Suffixes in sorted order:")
    for i, pos in enumerate(suffix_array):
        suffix = text[pos:min(pos + 15, len(text))]  # Show first 15 chars of suffix
        #print(f"  {i}: [{pos}] '{suffix}{'...' if pos + 15 < len(text) else ''}'")
    
    print("\n--- FINDING FIRST OCCURRENCE ---")
    
    # Binary search to find the first occurrence
    left, right = 0, n - 1
    first_occurrence = -1
    
    print(f"Initial search range: left={left}, right={right}")
    
    iteration = 1
    while left <= right:
        mid = (left + right) // 2
        suffix_start = suffix_array[mid]
        suffix = text[suffix_start:min(suffix_start + query_len, len(text))]
        
        print(f"\nIteration {iteration}:")
        print(f"  mid={mid}, suffix_start={suffix_start}")
        print(f"  Comparing query '{query}' with suffix '{suffix}'")
        
        if suffix < query:
            print(f"  Suffix '{suffix}' < query '{query}', moving right")
            left = mid + 1
            print(f"  New range: left={left}, right={right}")
        elif suffix > query:
            print(f"  Suffix '{suffix}' > query '{query}', moving left")
            right = mid - 1
            print(f"  New range: left={left}, right={right}")
        else:
            print(f"  Match found! Suffix '{suffix}' == query '{query}'")
            print(f"  Setting first_occurrence={mid} and continuing leftward")
            first_occurrence = mid
            right = mid - 1
            print(f"  New range: left={left}, right={right}")
        
        iteration += 1
    
    # If no occurrence found, return empty list
    if first_occurrence == -1:
        print("\nNo occurrences found.")
        return []
    
    print(f"\nFirst occurrence found at index {first_occurrence} in suffix array (position {suffix_array[first_occurrence]} in text)")
    
    print("\n--- FINDING LAST OCCURRENCE ---")
    
    # Binary search to find the last occurrence
    left, right = first_occurrence, n - 1
    last_occurrence = first_occurrence
    
    print(f"Initial search range: left={left}, right={right}")
    
    iteration = 1
    while left <= right:
        mid = (left + right) // 2
        suffix_start = suffix_array[mid]
        suffix = text[suffix_start:min(suffix_start + query_len, len(text))]
        
        print(f"\nIteration {iteration}:")
        print(f"  mid={mid}, suffix_start={suffix_start}")
        print(f"  Comparing query '{query}' with suffix '{suffix}'")
        
        if suffix < query:
            print(f"  Suffix '{suffix}' < query '{query}', moving right")
            left = mid + 1
            print(f"  New range: left={left}, right={right}")
        elif suffix > query:
            print(f"  Suffix '{suffix}' > query '{query}', moving left")
            right = mid - 1
            print(f"  New range: left={left}, right={right}")
        else:
            print(f"  Match found! Suffix '{suffix}' == query '{query}'")
            print(f"  Setting last_occurrence={mid} and continuing rightward")
            last_occurrence = mid
            left = mid + 1
            print(f"  New range: left={left}, right={right}")
        
        iteration += 1
    
    print(f"\nLast occurrence found at index {last_occurrence} in suffix array (position {suffix_array[last_occurrence]} in text)")
    
    # Collect all positions
    print("\n--- COLLECTING ALL POSITIONS ---")
    print(suffix_array[first_occurrence:last_occurrence + 1])
    for i in range(first_occurrence, last_occurrence + 1):
        print(f"Adding position {suffix_array[i]} from suffix array index {i}")
        positions.append(suffix_array[i])
    
    print(f"\nFinal result: Query '{query}' found at positions {positions} in the text")
    
    return positions

# %%
text = """En un mundo donde la información fluye sin cesar, la capacidad de analizar, sintetizar y comprender grandes volúmenes de datos se ha convertido en una habilidad esencial. La era digital ha transformado la forma en que las personas interactúan con el conocimiento, permitiendo un acceso casi ilimitado a textos, estudios, investigaciones y opiniones de todas partes del mundo. Sin embargo, este acceso masivo también ha generado nuevos desafíos, como la sobrecarga de información y la dificultad para discernir entre fuentes confiables y aquellas que no lo son.

Desde tiempos antiguos, el ser humano ha buscado recopilar y organizar el conocimiento. Bibliotecas como la de Alejandría en el Egipto antiguo fueron testimonio de esta ambición, albergando miles de rollos y manuscritos que contenían la sabiduría de civilizaciones enteras. Con el paso del tiempo, la invención de la imprenta por Gutenberg en el siglo XV revolucionó la distribución del conocimiento, permitiendo la producción masiva de libros y facilitando el acceso a la educación. Hoy en día, el internet ha llevado esta democratización del saber a niveles inimaginables hace apenas unas décadas.

A pesar de los beneficios evidentes, la disponibilidad de información también ha traído consigo el problema de la desinformación. En la actualidad, la propagación de noticias falsas, teorías conspirativas y datos erróneos se ha convertido en una preocupación global. Las redes sociales han facilitado la viralización de contenidos, lo que a menudo contribuye a la confusión y polarización de la sociedad. Para combatir este fenómeno, es fundamental fomentar el pensamiento crítico, la alfabetización mediática y la educación digital.

El pensamiento crítico implica la capacidad de analizar argumentos, evaluar evidencia y cuestionar la veracidad de las fuentes. En un mundo donde la información se presenta en formatos atractivos y persuasivos, es esencial desarrollar la habilidad de distinguir entre hechos y opiniones, así como identificar sesgos en los discursos. La alfabetización mediática, por su parte, permite a las personas comprender cómo funcionan los medios de comunicación, reconocer las estrategias utilizadas para influir en la opinión pública y desarrollar un consumo de información más responsable.

La educación digital también juega un papel crucial en este contexto. A medida que la tecnología avanza, es fundamental que las personas adquieran competencias digitales que les permitan navegar con seguridad en el entorno digital. Esto incluye el conocimiento sobre ciberseguridad, privacidad en línea y el uso de herramientas de verificación de información. Organizaciones y gobiernos de todo el mundo han comenzado a implementar programas de educación digital en escuelas y universidades para preparar a las nuevas generaciones para los desafíos del siglo XXI.

Además de los aspectos educativos, el acceso a la información ha impactado significativamente en el ámbito laboral y empresarial. En el mundo actual, las decisiones estratégicas en las empresas dependen en gran medida del análisis de datos y la interpretación de tendencias. Las organizaciones que logran aprovechar la información de manera efectiva pueden obtener ventajas competitivas, mejorar sus procesos y ofrecer productos y servicios más alineados con las necesidades del mercado. En este sentido, la analítica de datos y la inteligencia artificial han cobrado gran relevancia, permitiendo procesar grandes volúmenes de información en tiempo real y facilitando la toma de decisiones basada en evidencia.

Por otro lado, la transformación digital también ha impulsado cambios en los modelos de negocio y en la forma en que las empresas interactúan con los clientes. La personalización de servicios, el comercio electrónico y las plataformas digitales han redefinido la experiencia del consumidor, brindando nuevas oportunidades para el crecimiento empresarial. Sin embargo, estos avances también han generado preocupaciones sobre la privacidad de los datos, la seguridad cibernética y el impacto de la automatización en el empleo.

En el ámbito social, la digitalización ha facilitado la comunicación y la colaboración a nivel global. Las redes sociales han permitido a las personas mantenerse conectadas con amigos y familiares, compartir ideas y participar en movimientos sociales. No obstante, también han dado lugar a fenómenos como la polarización ideológica, el ciberacoso y la manipulación de la opinión pública. Para mitigar estos efectos negativos, es necesario promover un uso ético y responsable de la tecnología, así como desarrollar regulaciones que protejan la integridad de los usuarios.

Otro aspecto importante a considerar es el impacto ambiental del uso masivo de la tecnología. La producción y el desecho de dispositivos electrónicos, el consumo de energía de los centros de datos y la huella de carbono de las actividades digitales son factores que deben abordarse con urgencia. Empresas y gobiernos han comenzado a implementar estrategias de sostenibilidad, como la adopción de energías renovables, el reciclaje de componentes electrónicos y el desarrollo de tecnologías más eficientes.

En conclusión, la era digital ha traído consigo innumerables beneficios, pero también desafíos que requieren atención y acción inmediata. La capacidad de analizar información de manera crítica, el desarrollo de competencias digitales y la promoción de un uso ético de la tecnología son aspectos clave para aprovechar el potencial de la era digital sin caer en sus riesgos. A medida que la sociedad avanza, es fundamental encontrar un equilibrio entre el progreso tecnológico y la responsabilidad social, asegurando que el conocimiento y la información sigan siendo herramientas para el desarrollo y el bienestar de la humanidad."""


#text = "muy buenos dias mundo cruel y despiadado"
suffix_array = build_suffix_array(text)
queries = ["beneficios", "dis", "mundo", "X"]

results = []
for query in queries:
    positions = binary_search(text, suffix_array, query)
    results.append((query, positions))

for r in results: 
    print(r)
    for idx in r[1]:
        print(text[idx:idx+len(r[0])])
# Out:
# --- FINDING FIRST OCCURRENCE ---
# Initial search range: left=0, right=5790
#
# Iteration 1:
#   mid=2895, suffix_start=1781
#   Comparing query 'beneficios' with suffix 'ia y cuest'
#   Suffix 'ia y cuest' > query 'beneficios', moving left
#   New range: left=0, right=2894
#
# Iteration 2:
#   mid=1447, suffix_start=1569
#   Comparing query 'beneficios' with suffix 'ara combat'
#   Suffix 'ara combat' < query 'beneficios', moving right
#   New range: left=1448, right=2894
#
# Iteration 3:
#   mid=2171, suffix_start=1500
#   Comparing query 'beneficios' with suffix 'e a menudo'
#   Suffix 'e a menudo' > query 'beneficios', moving left
#   New range: left=1448, right=2170
#
# Iteration 4:
#   mid=1809, suffix_start=5436
#   Comparing query 'beneficios' with suffix 'cnología s'
#   Suffix 'cnología s' > query 'beneficios', moving left
#   New range: left=1448, right=1808
#
# Iteration 5:
#   mid=1628, suffix_start=3409
#   Comparing query 'beneficios' with suffix 'brado gran'
#   Suffix 'brado gran' > query 'beneficios', moving left
#   New range: left=1448, right=1627
#
# Iteration 6:
#   mid=1537, suffix_start=990
#   Comparing query 'beneficios' with suffix 'asiva de l'
#   Suffix 'asiva de l' < query 'beneficios', moving right
#   New range: left=1538, right=1627
#
# Iteration 7:
#   mid=1582, suffix_start=4925
#   Comparing query 'beneficios' with suffix 'ben aborda'
#   Suffix 'ben aborda' < query 'beneficios', moving right
#   New range: left=1583, right=1627
#
# Iteration 8:
#   mid=1605, suffix_start=2949
#   Comparing query 'beneficios' with suffix 'bito labor'
#   Suffix 'bito labor' > query 'beneficios', moving left
#   New range: left=1583, right=1604
#
# Iteration 9:
#   mid=1593, suffix_start=733
#   Comparing query 'beneficios' with suffix 'bición, al'
#   Suffix 'bición, al' > query 'beneficios', moving left
#   New range: left=1583, right=1592
#
# Iteration 10:
#   mid=1587, suffix_start=897
#   Comparing query 'beneficios' with suffix 'berg en el'
#   Suffix 'berg en el' > query 'beneficios', moving left
#   New range: left=1583, right=1586
#
# Iteration 11:
#   mid=1584, suffix_start=5224
#   Comparing query 'beneficios' with suffix 'beneficios'
#   Match found! Suffix 'beneficios' == query 'beneficios'
#   Setting first_occurrence=1584 and continuing leftward
#   New range: left=1583, right=1583
#
# Iteration 12:
#   mid=1583, suffix_start=1178
#   Comparing query 'beneficios' with suffix 'beneficios'
#   Match found! Suffix 'beneficios' == query 'beneficios'
#   Setting first_occurrence=1583 and continuing leftward
#   New range: left=1583, right=1582
#
# First occurrence found at index 1583 in suffix array (position 1178 in text)
#
# --- FINDING LAST OCCURRENCE ---
# Initial search range: left=1583, right=5790
#
# Iteration 1:
#   mid=3686, suffix_start=2111
#   Comparing query 'beneficios' with suffix 'mo funcion'
#   Suffix 'mo funcion' > query 'beneficios', moving left
#   New range: left=1583, right=3685
#
# Iteration 2:
#   mid=2634, suffix_start=1437
#   Comparing query 'beneficios' with suffix 'es sociale'
#   Suffix 'es sociale' > query 'beneficios', moving left
#   New range: left=1583, right=2633
#
# Iteration 3:
#   mid=2108, suffix_start=2052
#   Comparing query 'beneficios' with suffix 'diática, p'
#   Suffix 'diática, p' > query 'beneficios', moving left
#   New range: left=1583, right=2107
#
# Iteration 4:
#   mid=1845, suffix_start=2477
#   Comparing query 'beneficios' with suffix 'con seguri'
#   Suffix 'con seguri' > query 'beneficios', moving left
#   New range: left=1583, right=1844
#
# Iteration 5:
#   mid=1713, suffix_start=4329
#   Comparing query 'beneficios' with suffix 'ciales. No'
#   Suffix 'ciales. No' > query 'beneficios', moving left
#   New range: left=1583, right=1712
#
# Iteration 6:
#   mid=1647, suffix_start=2057
#   Comparing query 'beneficios' with suffix 'ca, por su'
#   Suffix 'ca, por su' > query 'beneficios', moving left
#   New range: left=1583, right=1646
#
# Iteration 7:
#   mid=1614, suffix_start=4556
#   Comparing query 'beneficios' with suffix 'ble de la '
#   Suffix 'ble de la ' > query 'beneficios', moving left
#   New range: left=1583, right=1613
#
# Iteration 8:
#   mid=1598, suffix_start=4966
#   Comparing query 'beneficios' with suffix 'biernos ha'
#   Suffix 'biernos ha' > query 'beneficios', moving left
#   New range: left=1583, right=1597
#
# Iteration 9:
#   mid=1590, suffix_start=2551
#   Comparing query 'beneficios' with suffix 'bersegurid'
#   Suffix 'bersegurid' > query 'beneficios', moving left
#   New range: left=1583, right=1589
#
# Iteration 10:
#   mid=1586, suffix_start=4423
#   Comparing query 'beneficios' with suffix 'beracoso y'
#   Suffix 'beracoso y' > query 'beneficios', moving left
#   New range: left=1583, right=1585
#
# Iteration 11:
#   mid=1584, suffix_start=5224
#   Comparing query 'beneficios' with suffix 'beneficios'
#   Match found! Suffix 'beneficios' == query 'beneficios'
#   Setting last_occurrence=1584 and continuing rightward
#   New range: left=1585, right=1585
#
# Iteration 12:
#   mid=1585, suffix_start=1108
#   Comparing query 'beneficios' with suffix 'ber a nive'
#   Suffix 'ber a nive' > query 'beneficios', moving left
#   New range: left=1585, right=1584
#
# Last occurrence found at index 1584 in suffix array (position 5224 in text)
#
# --- COLLECTING ALL POSITIONS ---
# [1178, 5224]
# Adding position 1178 from suffix array index 1583
# Adding position 5224 from suffix array index 1584
#
# Final result: Query 'beneficios' found at positions [1178, 5224] in the text
#
# --- FINDING FIRST OCCURRENCE ---
# Initial search range: left=0, right=5790
#
# Iteration 1:
#   mid=2895, suffix_start=1781
#   Comparing query 'dis' with suffix 'ia '
#   Suffix 'ia ' > query 'dis', moving left
#   New range: left=0, right=2894
#
# Iteration 2:
#   mid=1447, suffix_start=1569
#   Comparing query 'dis' with suffix 'ara'
#   Suffix 'ara' < query 'dis', moving right
#   New range: left=1448, right=2894
#
# Iteration 3:
#   mid=2171, suffix_start=1500
#   Comparing query 'dis' with suffix 'e a'
#   Suffix 'e a' > query 'dis', moving left
#   New range: left=1448, right=2170
#
# Iteration 4:
#   mid=1809, suffix_start=5436
#   Comparing query 'dis' with suffix 'cno'
#   Suffix 'cno' < query 'dis', moving right
#   New range: left=1810, right=2170
#
# Iteration 5:
#   mid=1990, suffix_start=4819
#   Comparing query 'dis' with suffix 'de '
#   Suffix 'de ' < query 'dis', moving right
#   New range: left=1991, right=2170
#
# Iteration 6:
#   mid=2080, suffix_start=1277
#   Comparing query 'dis' with suffix 'des'
#   Suffix 'des' < query 'dis', moving right
#   New range: left=2081, right=2170
#
# Iteration 7:
#   mid=2125, suffix_start=3412
#   Comparing query 'dis' with suffix 'do '
#   Suffix 'do ' > query 'dis', moving left
#   New range: left=2081, right=2124
#
# Iteration 8:
#   mid=2102, suffix_start=2021
#   Comparing query 'dis' with suffix 'dis'
#   Match found! Suffix 'dis' == query 'dis'
#   Setting first_occurrence=2102 and continuing leftward
#   New range: left=2081, right=2101
#
# Iteration 9:
#   mid=2091, suffix_start=2295
#   Comparing query 'dis' with suffix 'dig'
#   Suffix 'dig' < query 'dis', moving right
#   New range: left=2092, right=2101
#
# Iteration 10:
#   mid=2096, suffix_start=4896
#   Comparing query 'dis' with suffix 'dig'
#   Suffix 'dig' < query 'dis', moving right
#   New range: left=2097, right=2101
#
# Iteration 11:
#   mid=2099, suffix_start=2130
#   Comparing query 'dis' with suffix 'dio'
#   Suffix 'dio' < query 'dis', moving right
#   New range: left=2100, right=2101
#
# Iteration 12:
#   mid=2100, suffix_start=315
#   Comparing query 'dis' with suffix 'dio'
#   Suffix 'dio' < query 'dis', moving right
#   New range: left=2101, right=2101
#
# Iteration 13:
#   mid=2101, suffix_start=500
#   Comparing query 'dis' with suffix 'dis'
#   Match found! Suffix 'dis' == query 'dis'
#   Setting first_occurrence=2101 and continuing leftward
#   New range: left=2101, right=2100
#
# First occurrence found at index 2101 in suffix array (position 500 in text)
#
# --- FINDING LAST OCCURRENCE ---
# Initial search range: left=2101, right=5790
#
# Iteration 1:
#   mid=3945, suffix_start=3955
#   Comparing query 'dis' with suffix 'ner'
#   Suffix 'ner' > query 'dis', moving left
#   New range: left=2101, right=3944
#
# Iteration 2:
#   mid=3022, suffix_start=2537
#   Comparing query 'dis' with suffix 'ien'
#   Suffix 'ien' > query 'dis', moving left
#   New range: left=2101, right=3021
#
# Iteration 3:
#   mid=2561, suffix_start=830
#   Comparing query 'dis' with suffix 'era'
#   Suffix 'era' > query 'dis', moving left
#   New range: left=2101, right=2560
#
# Iteration 4:
#   mid=2330, suffix_start=4501
#   Comparing query 'dis' with suffix 'ega'
#   Suffix 'ega' > query 'dis', moving left
#   New range: left=2101, right=2329
#
# Iteration 5:
#   mid=2215, suffix_start=465
#   Comparing query 'dis' with suffix 'e i'
#   Suffix 'e i' > query 'dis', moving left
#   New range: left=2101, right=2214
#
# Iteration 6:
#   mid=2157, suffix_start=2286
#   Comparing query 'dis' with suffix 'duc'
#   Suffix 'duc' > query 'dis', moving left
#   New range: left=2101, right=2156
#
# Iteration 7:
#   mid=2128, suffix_start=4135
#   Comparing query 'dis' with suffix 'do '
#   Suffix 'do ' > query 'dis', moving left
#   New range: left=2101, right=2127
#
# Iteration 8:
#   mid=2114, suffix_start=3618
#   Comparing query 'dis' with suffix 'do '
#   Suffix 'do ' > query 'dis', moving left
#   New range: left=2101, right=2113
#
# Iteration 9:
#   mid=2107, suffix_start=1665
#   Comparing query 'dis' with suffix 'diá'
#   Suffix 'diá' > query 'dis', moving left
#   New range: left=2101, right=2106
#
# Iteration 10:
#   mid=2103, suffix_start=1203
#   Comparing query 'dis' with suffix 'dis'
#   Match found! Suffix 'dis' == query 'dis'
#   Setting last_occurrence=2103 and continuing rightward
#   New range: left=2104, right=2106
#
# Iteration 11:
#   mid=2105, suffix_start=1949
#   Comparing query 'dis' with suffix 'dis'
#   Match found! Suffix 'dis' == query 'dis'
#   Setting last_occurrence=2105 and continuing rightward
#   New range: left=2106, right=2106
#
# Iteration 12:
#   mid=2106, suffix_start=932
#   Comparing query 'dis' with suffix 'dis'
#   Match found! Suffix 'dis' == query 'dis'
#   Setting last_occurrence=2106 and continuing rightward
#   New range: left=2107, right=2106
#
# Last occurrence found at index 2106 in suffix array (position 932 in text)
#
# --- COLLECTING ALL POSITIONS ---
# [500, 2021, 1203, 4781, 1949, 932]
# Adding position 500 from suffix array index 2101
# Adding position 2021 from suffix array index 2102
# Adding position 1203 from suffix array index 2103
# Adding position 4781 from suffix array index 2104
# Adding position 1949 from suffix array index 2105
# Adding position 932 from suffix array index 2106
#
# Final result: Query 'dis' found at positions [500, 2021, 1203, 4781, 1949, 932] in the text
#
# --- FINDING FIRST OCCURRENCE ---
# Initial search range: left=0, right=5790
#
# Iteration 1:
#   mid=2895, suffix_start=1781
#   Comparing query 'mundo' with suffix 'ia y '
#   Suffix 'ia y ' < query 'mundo', moving right
#   New range: left=2896, right=5790
#
# Iteration 2:
#   mid=4343, suffix_start=5094
#   Comparing query 'mundo' with suffix 'onent'
#   Suffix 'onent' > query 'mundo', moving left
#   New range: left=2896, right=4342
#
# Iteration 3:
#   mid=3619, suffix_start=381
#   Comparing query 'mundo' with suffix 'mbarg'
#   Suffix 'mbarg' < query 'mundo', moving right
#   New range: left=3620, right=4342
#
# Iteration 4:
#   mid=3981, suffix_start=5022
#   Comparing query 'mundo' with suffix 'nibil'
#   Suffix 'nibil' > query 'mundo', moving left
#   New range: left=3620, right=3980
#
# Iteration 5:
#   mid=3800, suffix_start=2907
#   Comparing query 'mundo' with suffix 'n ha '
#   Suffix 'n ha ' > query 'mundo', moving left
#   New range: left=3620, right=3799
#
# Iteration 6:
#   mid=3709, suffix_start=3492
#   Comparing query 'mundo' with suffix 'mpo r'
#   Suffix 'mpo r' < query 'mundo', moving right
#   New range: left=3710, right=3799
#
# Iteration 7:
#   mid=3754, suffix_start=2624
#   Comparing query 'mundo' with suffix 'n de '
#   Suffix 'n de ' > query 'mundo', moving left
#   New range: left=3710, right=3753
#
# Iteration 8:
#   mid=3731, suffix_start=2850
#   Comparing query 'mundo' with suffix 'más d'
#   Suffix 'más d' > query 'mundo', moving left
#   New range: left=3710, right=3730
#
# Iteration 9:
#   mid=3720, suffix_start=3681
#   Comparing query 'mundo' with suffix 'mpres'
#   Suffix 'mpres' < query 'mundo', moving right
#   New range: left=3721, right=3730
#
# Iteration 10:
#   mid=3725, suffix_start=1832
#   Comparing query 'mundo' with suffix 'mundo'
#   Match found! Suffix 'mundo' == query 'mundo'
#   Setting first_occurrence=3725 and continuing leftward
#   New range: left=3721, right=3724
#
# Iteration 11:
#   mid=3722, suffix_start=3612
#   Comparing query 'mundo' with suffix 'mpuls'
#   Suffix 'mpuls' < query 'mundo', moving right
#   New range: left=3723, right=3724
#
# Iteration 12:
#   mid=3723, suffix_start=2983
#   Comparing query 'mundo' with suffix 'mundo'
#   Match found! Suffix 'mundo' == query 'mundo'
#   Setting first_occurrence=3723 and continuing leftward
#   New range: left=3723, right=3722
#
# First occurrence found at index 3723 in suffix array (position 2983 in text)
#
# --- FINDING LAST OCCURRENCE ---
# Initial search range: left=3723, right=5790
#
# Iteration 1:
#   mid=4756, suffix_start=5062
#   Comparing query 'mundo' with suffix 'renov'
#   Suffix 'renov' > query 'mundo', moving left
#   New range: left=3723, right=4755
#
# Iteration 2:
#   mid=4239, suffix_start=454
#   Comparing query 'mundo' with suffix 'obrec'
#   Suffix 'obrec' > query 'mundo', moving left
#   New range: left=3723, right=4238
#
# Iteration 3:
#   mid=3980, suffix_start=1208
#   Comparing query 'mundo' with suffix 'nibil'
#   Suffix 'nibil' > query 'mundo', moving left
#   New range: left=3723, right=3979
#
# Iteration 4:
#   mid=3851, suffix_start=5416
#   Comparing query 'mundo' with suffix 'n uso'
#   Suffix 'n uso' > query 'mundo', moving left
#   New range: left=3723, right=3850
#
# Iteration 5:
#   mid=3786, suffix_start=5595
#   Comparing query 'mundo' with suffix 'n equ'
#   Suffix 'n equ' > query 'mundo', moving left
#   New range: left=3723, right=3785
#
# Iteration 6:
#   mid=3754, suffix_start=2624
#   Comparing query 'mundo' with suffix 'n de '
#   Suffix 'n de ' > query 'mundo', moving left
#   New range: left=3723, right=3753
#
# Iteration 7:
#   mid=3738, suffix_start=3150
#   Comparing query 'mundo' with suffix 'n apr'
#   Suffix 'n apr' > query 'mundo', moving left
#   New range: left=3723, right=3737
#
# Iteration 8:
#   mid=3730, suffix_start=3288
#   Comparing query 'mundo' with suffix 'más a'
#   Suffix 'más a' > query 'mundo', moving left
#   New range: left=3723, right=3729
#
# Iteration 9:
#   mid=3726, suffix_start=2680
#   Comparing query 'mundo' with suffix 'mundo'
#   Match found! Suffix 'mundo' == query 'mundo'
#   Setting last_occurrence=3726 and continuing rightward
#   New range: left=3727, right=3729
#
# Iteration 10:
#   mid=3728, suffix_start=4143
#   Comparing query 'mundo' with suffix 'munic'
#   Suffix 'munic' > query 'mundo', moving left
#   New range: left=3727, right=3727
#
# Iteration 11:
#   mid=3727, suffix_start=369
#   Comparing query 'mundo' with suffix 'mundo'
#   Match found! Suffix 'mundo' == query 'mundo'
#   Setting last_occurrence=3727 and continuing rightward
#   New range: left=3728, right=3727
#
# Last occurrence found at index 3727 in suffix array (position 369 in text)
#
# --- COLLECTING ALL POSITIONS ---
# [2983, 6, 1832, 2680, 369]
# Adding position 2983 from suffix array index 3723
# Adding position 6 from suffix array index 3724
# Adding position 1832 from suffix array index 3725
# Adding position 2680 from suffix array index 3726
# Adding position 369 from suffix array index 3727
#
# Final result: Query 'mundo' found at positions [2983, 6, 1832, 2680, 369] in the text
#
# --- FINDING FIRST OCCURRENCE ---
# Initial search range: left=0, right=5790
#
# Iteration 1:
#   mid=2895, suffix_start=1781
#   Comparing query 'X' with suffix 'i'
#   Suffix 'i' > query 'X', moving left
#   New range: left=0, right=2894
#
# Iteration 2:
#   mid=1447, suffix_start=1569
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=0, right=1446
#
# Iteration 3:
#   mid=723, suffix_start=2151
#   Comparing query 'X' with suffix ' '
#   Suffix ' ' < query 'X', moving right
#   New range: left=724, right=1446
#
# Iteration 4:
#   mid=1085, suffix_start=2892
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=724, right=1084
#
# Iteration 5:
#   mid=904, suffix_start=858
#   Comparing query 'X' with suffix ','
#   Suffix ',' < query 'X', moving right
#   New range: left=905, right=1084
#
# Iteration 6:
#   mid=994, suffix_start=376
#   Comparing query 'X' with suffix 'S'
#   Suffix 'S' < query 'X', moving right
#   New range: left=995, right=1084
#
# Iteration 7:
#   mid=1039, suffix_start=4107
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=995, right=1038
#
# Iteration 8:
#   mid=1016, suffix_start=4139
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=995, right=1015
#
# Iteration 9:
#   mid=1005, suffix_start=3353
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=995, right=1004
#
# Iteration 10:
#   mid=999, suffix_start=2841
#   Comparing query 'X' with suffix 'X'
#   Match found! Suffix 'X' == query 'X'
#   Setting first_occurrence=999 and continuing leftward
#   New range: left=995, right=998
#
# Iteration 11:
#   mid=996, suffix_start=915
#   Comparing query 'X' with suffix 'V'
#   Suffix 'V' < query 'X', moving right
#   New range: left=997, right=998
#
# Iteration 12:
#   mid=997, suffix_start=2842
#   Comparing query 'X' with suffix 'X'
#   Match found! Suffix 'X' == query 'X'
#   Setting first_occurrence=997 and continuing leftward
#   New range: left=997, right=996
#
# First occurrence found at index 997 in suffix array (position 2842 in text)
#
# --- FINDING LAST OCCURRENCE ---
# Initial search range: left=997, right=5790
#
# Iteration 1:
#   mid=3393, suffix_start=4156
#   Comparing query 'X' with suffix 'l'
#   Suffix 'l' > query 'X', moving left
#   New range: left=997, right=3392
#
# Iteration 2:
#   mid=2194, suffix_start=4921
#   Comparing query 'X' with suffix 'e'
#   Suffix 'e' > query 'X', moving left
#   New range: left=997, right=2193
#
# Iteration 3:
#   mid=1595, suffix_start=5765
#   Comparing query 'X' with suffix 'b'
#   Suffix 'b' > query 'X', moving left
#   New range: left=997, right=1594
#
# Iteration 4:
#   mid=1295, suffix_start=1609
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1294
#
# Iteration 5:
#   mid=1145, suffix_start=4950
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1144
#
# Iteration 6:
#   mid=1070, suffix_start=877
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1069
#
# Iteration 7:
#   mid=1033, suffix_start=1084
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1032
#
# Iteration 8:
#   mid=1014, suffix_start=4157
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1013
#
# Iteration 9:
#   mid=1005, suffix_start=3353
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=1004
#
# Iteration 10:
#   mid=1000, suffix_start=1297
#   Comparing query 'X' with suffix 'a'
#   Suffix 'a' > query 'X', moving left
#   New range: left=997, right=999
#
# Iteration 11:
#   mid=998, suffix_start=914
#   Comparing query 'X' with suffix 'X'
#   Match found! Suffix 'X' == query 'X'
#   Setting last_occurrence=998 and continuing rightward
#   New range: left=999, right=999
#
# Iteration 12:
#   mid=999, suffix_start=2841
#   Comparing query 'X' with suffix 'X'
#   Match found! Suffix 'X' == query 'X'
#   Setting last_occurrence=999 and continuing rightward
#   New range: left=1000, right=999
#
# Last occurrence found at index 999 in suffix array (position 2841 in text)
#
# --- COLLECTING ALL POSITIONS ---
# [2842, 914, 2841]
# Adding position 2842 from suffix array index 997
# Adding position 914 from suffix array index 998
# Adding position 2841 from suffix array index 999
#
# Final result: Query 'X' found at positions [2842, 914, 2841] in the text
# ('beneficios', [1178, 5224])
# beneficios
# beneficios
# ('dis', [500, 2021, 1203, 4781, 1949, 932])
# dis
# dis
# dis
# dis
# dis
# dis
# ('mundo', [2983, 6, 1832, 2680, 369])
# mundo
# mundo
# mundo
# mundo
# mundo
# ('X', [2842, 914, 2841])
# X
# X
# X

# %%
print(text[3758:3758+5])
print(text[1918:1918+5])
# Out:
# GGAAA
# AAACT
